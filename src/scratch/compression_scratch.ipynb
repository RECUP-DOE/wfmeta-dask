# %%
import pickle
import sys

sys.path.append('../')

from dask_capture import extract_scheduler_metadata, extract_worker_xfer_metadata
from dask_md_objs import TaskHandler

# %%
debug = True
exp_name = "D2024-04-18_15:54:02_R1_W8"
sched_trans_file = f"../{exp_name}/scheduler_transition.csv"
worker_xfer_file = f"../{exp_name}/worker_transfer.csv"
worker_trans_file = f"../{exp_name}/worker_transition.csv"

th = TaskHandler()
extract_scheduler_metadata(sched_trans_file, None, debug, th)
extract_worker_xfer_metadata(worker_xfer_file, None, debug, th)

with open('handler.pickle', 'wb') as f:
    pickle.dump(th, f, pickle.HIGHEST_PROTOCOL)
    # goes from 20MB down to 6MB; not awful
    # raw files are 13MB (scheduler_transition.csv + worker_transfer.csv)
# Out:
# 5440
# Task object for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0):
# 	Event objects:
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:54:41.430816	Begin time: None	End time: None
# 			Start: released				Finish: waiting
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: update-graph-1713455680.1067564
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:54:41.461591	Begin time: None	End time: None
# 			Start: waiting				Finish: processing
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: update-graph-1713455680.1067564
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:54:43.313033	Begin time: 2024-04-18 11:54:43.680709	End time: 2024-04-18 11:54:43.680875
# 			Start: processing				Finish: memory
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: task-finished-1713455683.2842815
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:54:50.276962	Begin time: None	End time: None
# 			Start: memory				Finish: released
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: task-finished-1713455689.9279013
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:55:23.283244	Begin time: None	End time: None
# 			Start: released				Finish: forgotten
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: client-releases-keys-1713455722.3023508
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:55:24.559761	Begin time: None	End time: None
# 			Start: released				Finish: waiting
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: update-graph-1713455724.3191612
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:55:24.631718	Begin time: None	End time: None
# 			Start: waiting				Finish: processing
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: update-graph-1713455724.3191612
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:55:33.062151	Begin time: 2024-04-18 11:55:33.626772	End time: 2024-04-18 11:55:33.626966
# 			Start: processing				Finish: memory
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: task-finished-1713455732.9909992
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:55:36.613818	Begin time: None	End time: None
# 			Start: memory				Finish: released
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: task-finished-1713455736.0379179
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:56:35.535567	Begin time: None	End time: None
# 			Start: released				Finish: forgotten
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: client-releases-keys-1713455793.8739438
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:56:36.278600	Begin time: None	End time: None
# 			Start: released				Finish: waiting
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: update-graph-1713455796.103127
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:56:36.343668	Begin time: None	End time: None
# 			Start: waiting				Finish: processing
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: update-graph-1713455796.103127
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:56:48.060943	Begin time: 2024-04-18 11:56:50.698682	End time: 2024-04-18 11:56:50.698994
# 			Start: processing				Finish: memory
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: task-finished-1713455807.944632
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:56:50.694330	Begin time: None	End time: None
# 			Start: memory				Finish: released
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: task-finished-1713455810.5993106
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:57:58.931224	Begin time: None	End time: None
# 			Start: released				Finish: forgotten
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: client-releases-keys-1713455876.421544
# 	Start time: 2024-04-18 11:54:43.680709	End time: 2024-04-18 11:54:43.680875
#
# 7140
# Task object for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0):
# 	Event objects:
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:54:41.430816	Begin time: None	End time: None
# 			Start: released				Finish: waiting
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: update-graph-1713455680.1067564
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:54:41.461591	Begin time: None	End time: None
# 			Start: waiting				Finish: processing
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: update-graph-1713455680.1067564
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:54:43.313033	Begin time: 2024-04-18 11:54:43.680709	End time: 2024-04-18 11:54:43.680875
# 			Start: processing				Finish: memory
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: task-finished-1713455683.2842815
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:54:50.276962	Begin time: None	End time: None
# 			Start: memory				Finish: released
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: task-finished-1713455689.9279013
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:55:23.283244	Begin time: None	End time: None
# 			Start: released				Finish: forgotten
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: client-releases-keys-1713455722.3023508
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:55:24.559761	Begin time: None	End time: None
# 			Start: released				Finish: waiting
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: update-graph-1713455724.3191612
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:55:24.631718	Begin time: None	End time: None
# 			Start: waiting				Finish: processing
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: update-graph-1713455724.3191612
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:55:33.062151	Begin time: 2024-04-18 11:55:33.626772	End time: 2024-04-18 11:55:33.626966
# 			Start: processing				Finish: memory
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: task-finished-1713455732.9909992
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:55:36.613818	Begin time: None	End time: None
# 			Start: memory				Finish: released
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: task-finished-1713455736.0379179
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:56:35.535567	Begin time: None	End time: None
# 			Start: released				Finish: forgotten
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: client-releases-keys-1713455793.8739438
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:56:36.278600	Begin time: None	End time: None
# 			Start: released				Finish: waiting
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: update-graph-1713455796.103127
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:56:36.343668	Begin time: None	End time: None
# 			Start: waiting				Finish: processing
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: update-graph-1713455796.103127
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:56:48.060943	Begin time: 2024-04-18 11:56:50.698682	End time: 2024-04-18 11:56:50.698994
# 			Start: processing				Finish: memory
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: task-finished-1713455807.944632
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:56:50.694330	Begin time: None	End time: None
# 			Start: memory				Finish: released
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: task-finished-1713455810.5993106
# 		Scheduler Event for task ('block-info-_map_read_frame-c50155175b03e4c1ec9664317841e345', 127, 0, 0, 0)
# 			Event time: 2024-04-18 11:57:58.931224	Begin time: None	End time: None
# 			Start: released				Finish: forgotten
# 			Source:
# 				Called from: tcp://10.201.0.220:8786
# 				Stimulus ID: client-releases-keys-1713455876.421544
# 	Start time: 2024-04-18 11:54:43.680709	End time: 2024-04-18 11:54:43.680875
